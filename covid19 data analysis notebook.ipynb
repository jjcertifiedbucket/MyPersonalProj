# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('Modules are imported.')
# Out:
# Modules are imported.

# %%
## import 'Covid19_Confirmed_dataset.csv' from "."/Dataset" folder

# %%
corona_dataset_csv = pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
## Check the shape of the dataframe

corona_dataset_csv.shape
# Out:
# (266, 104)

# %%
## notice how longitude and latitude are not useful
## delete "Lat" and "Long" columns

## ** note that axis = 0 is x (rows) and axis = 1 is y (columns)

# %%
df = corona_dataset_csv.drop(["Lat", "Long"], axis=1)

# %%
df.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
### setting the dataset to df creates a copy of the dataset witout "Long" and "Lat" columns to permanently delete the columns, add 'inplace = true' ##

# %%
corona_dataset_csv.drop(["Lat", "Long"], axis=1, inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
## Country of Australia appears multiple times
## Aggregate Country/Region --> Province/State
## Province/State is not needed (this becomes the index)

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %%
# notice how the original dataset had (266, 104)
## it's because it's now showing just the country, not the states/province

corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %%
## VISUALIZING DATA RELATED TO A COUNTRY (CHINA EXAMPLE)

# %%
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
corona_dataset_aggregated.loc["Spain"].plot()



## add a legend to compare

plt.legend()

# %%
corona_dataset_aggregated.describe()
# Out:
#           1/22/20     1/23/20     1/24/20      1/25/20      1/26/20  \
# count  187.000000  187.000000  187.000000   187.000000   187.000000
# mean     2.967914    3.497326    5.032086     7.668449    11.326203
# std     40.071697   47.017656   67.271230   102.808451   151.725366
# min      0.000000    0.000000    0.000000     0.000000     0.000000
# 25%      0.000000    0.000000    0.000000     0.000000     0.000000
# 50%      0.000000    0.000000    0.000000     0.000000     0.000000
# 75%      0.000000    0.000000    0.000000     0.000000     0.000000
# max    548.000000  643.000000  920.000000  1406.000000  2075.000000
#
#            1/27/20      1/28/20      1/29/20      1/30/20      1/31/20  ...  \
# count   187.000000   187.000000   187.000000   187.000000   187.000000  ...
# mean     15.652406    29.828877    32.973262    44.032086    53.085561  ...
# std     210.370186   402.833903   445.097602   595.295516   716.748552  ...
# ...

# %%
## Calculating a good measure
## describing the spread of the virus in a country

# %%
corona_dataset_aggregated.loc['China'].plot()
plt.legend()

# %%
## evaluate the first 3 days

# %%
corona_dataset_aggregated.loc['China'][:3].plot()
# Out:
# <AxesSubplot:>

# %%
## notice the first day, 550 deaths confirmed.  100 confirmed deaths 24 hours after

# %%
## maximum infection rate in period? ; find the rate of the curve, derivative

# %%
## notice that 1/23 to 1/24 had a steeper rate, confirming 250 deaths in 24 hours

# %%
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
## in a single day, 15,136 new cases has been recorded

# %%
corona_dataset_aggregated.loc["Germany"].diff().plot()
plt.legend()

# %%
corona_dataset_aggregated.loc["Germany"].diff().max()
# Out:
# 6933.0

# %%
corona_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 9630.0

# %%
### FIND MAXIMUM INFECTION RATE FOR ALL COUNTRIES 
## create a new column showing the highest amount of death in a day 'max_infection_rates'

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = [] ## for loop
for c in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated['max_infection_rate'] = max_infection_rates ## note that this tab need be pushed back

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rate"])

# %%
corona_data.head(10)
# Out:
#                      max_infection_rate
# Country/Region
# Afghanistan                       232.0
# Albania                            34.0
# Algeria                           199.0
# Andorra                            43.0
# Angola                              5.0
# Antigua and Barbuda                 6.0
# Argentina                         291.0
# Armenia                           134.0
# Australia                         497.0
# Austria                          1321.0

# %%
corona_data.describe()
# Out:
#        max_infection_rate
# count          187.000000
# mean          1042.112299
# std           3781.896944
# min              1.000000
# 25%             19.000000
# 50%             73.000000
# 75%            355.500000
# max          36188.000000

# %%
## Import the WorldHappinessReport.csv dataset
## select needed columns for analysis, join datasets, calculate the correlations as the result
## of the analysis

# %%
happiness_report_csv = pd.read_csv("Datasets/worldwide_happiness_report.csv")

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
### take off columns that aren't useful for analyzing

# %%
useless_cols = ["Overall rank", "Score", "Generosity", "Perceptions of corruption"]

# %%
happiness_report_csv.drop(useless_cols, axis=1, inplace=True)
happiness_report_csv.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
## change the index as the country

# %%
happiness_report_csv.set_index("Country or region", inplace=True)

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
# Join the two datasets (corona and world happiness)

# %%
happiness_report_csv.shape
# Out:
# (156, 4)

# %%
corona_data.shape
# Out:
# (187, 1)

# %%
## notice the corona data has more rows, use INNER JOIN

# %%
data = corona_data.join(happiness_report_csv, how = "inner")
data.head(10)
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# Australia                 497.0           1.372           1.548
# Austria                  1321.0           1.376           1.475
# Azerbaijan                105.0           1.043           1.147
# Bahrain                   301.0           1.362           1.368
# Bangladesh                641.0           0.562           0.928
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# ...

# %%
## Correlation matrix, note that pivot is 1.0000 (no use), lower triangular matrix and upper triangular matrix
## are a reflection.  (LU)

# %%
data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %%
## Visualization of the results
## Plot GDP vs Maximum Infection Rate

# %%
x = data["GDP per capita"]
y = data["max_infection_rate"]
sns.scatterplot(x,y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
## GDP: monetary value of all the finished goods and services produced within a country
## in a specific time period (trades, transactions)
## observe that as GDP per capita grows, so does the max_inf_rate

# %%
# observer the x axis = (0,1.75)  & y axis = (0,25000) ; ratio is unmatched causing a compressed dot plots
# use log scaling instead

# %%
x = data["GDP per capita"]
y = data["max_infection_rate"]
sns.scatterplot(x=x,y=np.log(y)) ## specify the parameters so it results to no warning
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
sns.regplot(x=x,y=np.log(y)) ## regplot fits a line.
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
#Note that it shows there is a correlation, showing a positive slope

# %%
## Plot social support vs max inf rate

# %%
x = data["Social support"]
y = data["max_infection_rate"]
sns.regplot(x=x,y=np.log(y))
# Out:
# <AxesSubplot:xlabel='Social support', ylabel='max_infection_rate'>

# %%
 x = data["Healthy life expectancy"]
y = data["max_infection_rate"]
sns.regplot(x=x,y=np.log(y))
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_infection_rate'>

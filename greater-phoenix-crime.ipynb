# %% [markdown]
# <a href="https://www.kaggle.com/code/jonesroy/greater-phoenix-crime?scriptVersionId=99161974" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
pd.set_option('display.max_rows', None)
import datetime
from plotly.subplots import make_subplots

# %%
nRowsRead = 1000
data = pd.read_csv('../input/phoenix-crime-data/crimestat (1).csv', delimiter=',', nrows = nRowsRead, index_col='INC NUMBER')
data.dataframeName = 'crimestat (1).csv'

# %%
data.head()
# Out:
#                        OCCURRED ON        OCCURRED TO   UCR CRIME CATEGORY  \
# INC NUMBER
# 201600000052855  11/01/2015  00:00  01/09/2016  00:00  MOTOR VEHICLE THEFT
# 201600000594484  11/01/2015  00:00                NaN                 RAPE
# 201500002102327  11/01/2015  00:00  11/01/2015  09:00        LARCENY-THEFT
# 201500002101405  11/01/2015  00:00  11/01/2015  05:00  MOTOR VEHICLE THEFT
# 201500002102668  11/01/2015  00:00  11/01/2015  11:50  MOTOR VEHICLE THEFT
#
#                            100 BLOCK ADDR    ZIP         PREMISE TYPE
# INC NUMBER
# 201600000052855  N 43RD AVE & W CACTUS RD  85029  SINGLE FAMILY HOUSE
# 201600000594484         13XX E ALMERIA RD  85006  SINGLE FAMILY HOUSE
# 201500002102327            51XX N 15TH ST  85014            APARTMENT
# 201500002101405       102XX W MEDLOCK AVE  85307  SINGLE FAMILY HOUSE
# 201500002102668            69XX W WOOD ST  85043  SINGLE FAMILY HOUSE

# %%
def treemap(categories,title,path,values):
    fig = px.treemap(categories, path=path, values=values, height=700,
                 title=title, color_discrete_sequence = px.colors.sequential.RdBu)
    fig.data[0].textinfo = 'label+text+value'
    fig.show()

# %%
def histogram(data,path,color,title,xaxis,yaxis):
    fig = px.histogram(data, x=path,color=color)
    fig.update_layout(
        title_text=title,
        xaxis_title_text=xaxis, 
        yaxis_title_text=yaxis, 
        bargap=0.2, 
        bargroupgap=0.1
    )
    fig.show()

# %%
def bar(categories,x,y,color,title,xlab,ylab):
    fig = px.bar(categories, x=x, y=y,
             color=color,
             height=400)
    fig.update_layout(
    title_text=title, 
    xaxis_title_text=xlab, 
    yaxis_title_text=ylab,
    bargap=0.2, 
    bargroupgap=0.1
    )
    fig.show()

# %% [markdown]
# **General Analysis, number of crimes per cateory**

# %%
Number_crimes = data['UCR CRIME CATEGORY'].value_counts()
values = Number_crimes.values
categories = pd.DataFrame(data=Number_crimes.index, columns=["UCR CRIME CATEGORY"])
categories['values'] = values

# %%
treemap(categories,'Major Crimes in Greater Phoenix',['UCR CRIME CATEGORY'],categories['values'])
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
histogram(data,"UCR CRIME CATEGORY","UCR CRIME CATEGORY",'Major Crimes in Greater Phoenix','Crime','Count')
# Out:
# <div>                            <div id="6abcc864-71fd-43ad-a572-5a96bb6bc504" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6abcc864-71fd-43ad-a572-5a96bb6bc504")) {                    Plotly.newPlot(                        "6abcc864-71fd-43ad-a572-5a96bb6bc504",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "UCR CRIME CATEGORY=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "MOTOR VEHICLE THEFT", "marker": {"color": "#636efa"}, "name": "MOTOR VEHICLE THEFT", "offsetgroup": "MOTOR VEHICLE THEFT", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["MOTOR VEHICLE THEFT", "MOTOR VEHICLE THEFT", "MOTOR VEHICLE THEFT", "MOTOR VEHICLE THEFT", "MOTOR VEHICLE THEFT", "MOTOR VEHICLE THEFT", "MOTOR
# ...

# %%
bar(categories,categories['UCR CRIME CATEGORY'][0:10],categories['values'][0:10]
    ,categories['UCR CRIME CATEGORY'][0:10],'Top 10 Major Crimes in Greater Phoenix','Crime','Count')
# Out:
# <div>                            <div id="85bd45f9-a3f0-4c6d-9269-fbd4b8634456" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85bd45f9-a3f0-4c6d-9269-fbd4b8634456")) {                    Plotly.newPlot(                        "85bd45f9-a3f0-4c6d-9269-fbd4b8634456",                        [{"alignmentgroup": "True", "hovertemplate": "color=LARCENY-THEFT<br>x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "LARCENY-THEFT", "marker": {"color": "#636efa"}, "name": "LARCENY-THEFT", "offsetgroup": "LARCENY-THEFT", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["LARCENY-THEFT"], "xaxis": "x", "y": [477], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=BURGLARY<br>x=%{x}<br>y=%{y}<extra></extra>", "le
# ...

# %%
Number_crimes_street = data['100 BLOCK ADDR'].value_counts()
street = pd.DataFrame(data=Number_crimes_street.index, columns=["STREET"])
street['values'] = Number_crimes_street.values

# %%
bar(street,street['STREET'][0:10],street['values'][0:10]
    ,street['STREET'][0:10],'Top 10 Crime count on each Street','Street',' Crime Count')
# Out:
# <div>                            <div id="1bea71c6-c876-425a-ad0c-ccba529d3752" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bea71c6-c876-425a-ad0c-ccba529d3752")) {                    Plotly.newPlot(                        "1bea71c6-c876-425a-ad0c-ccba529d3752",                        [{"alignmentgroup": "True", "hovertemplate": "color=52XX W INDIAN SCHOOL RD<br>x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "52XX W INDIAN SCHOOL RD", "marker": {"color": "#636efa"}, "name": "52XX W INDIAN SCHOOL RD", "offsetgroup": "52XX W INDIAN SCHOOL RD", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["52XX W INDIAN SCHOOL RD"], "xaxis": "x", "y": [11], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=
# ...
